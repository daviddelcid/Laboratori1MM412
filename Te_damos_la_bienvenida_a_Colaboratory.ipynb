# %% [markdown]
# <a href="https://colab.research.google.com/github/daviddelcid/Laboratori1MM412/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
x=16
resultado= math.sqrt(x)
print(" La raiz cuadrad de 16 es ",resultado)
# Out:
#  La raiz cuadrad de 16 es  4.0

# %%
import numpy as np
arr= np.array([1,2,3,4])
# realizar una operacion sobre el array
squared = np.sqrt(arr)     # raiz cuadrada de cada elemento
print("La raiz cuadrada de los elementos son:",squared)
# Out:
# La raiz cuadrada de los elementos son: [1.         1.41421356 1.73205081 2.        ]

# %% [markdown]
# matplotlib.pyplot
# Se utiliza para crear gráficos y visualizar datos.

# %%
import matplotlib.pyplot as plt

x=np.linspace(-10,10,100)   # Generar 100 puntos de -10 a 10
y=x**2  # funcion cuadratica
plt.plot(x,y)
plt.title("grafico de f(x)= x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()
